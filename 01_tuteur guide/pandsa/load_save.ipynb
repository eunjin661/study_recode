# %%
# 여러가지 파일 형식 저장

import pandas as pd
df = pd.read_csv('서울특별시_강남구_불법주정차단속현황_20220207.csv',encoding='cp949',header=0)
df_2017 = df[df['연도'] == 2017]
df_2017.to_csv('2017.csv',encoding='utf-8')

# %%
# %pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\playdata\appdata\local\miniconda3\envs\new_01\lib\site-packages (2.0.48)
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\playdata\appdata\local\miniconda3\envs\new_01\lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\playdata\appdata\local\miniconda3\envs\new_01\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# mysql db 연동

from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

load_dotenv()

user_id = os.getenv('DB_USER')
user_pwd = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')
engine = create_engine(f'mysql+pymysql://{user_id}:{user_pwd}@localhost:3306/{db_name}')
conn = engine.connect()
result = conn.execute(text('select 1'))
print(result.fetchall())
conn.close()
# Out:
# [(1,)]
