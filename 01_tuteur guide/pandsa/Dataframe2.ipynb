# %%
import pandas as pd

file_path = '소상공인시장진흥공단_전국 온누리상품권 가맹점 현황_20250731 (1).csv'
df = pd.read_csv(file_path)
df.head()

# %%
df.drop([0,1])
df.drop('가맹점명',axis=1)

# %%
df['등록년도'].unique()
df['등록년도'].isin( [2020,2025] )
