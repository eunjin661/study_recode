# %%
import requests
import xml.etree.ElementTree as ET
import os
from dotenv import load_dotenv
load_dotenv()

service_key = os.getenv('PUBLIC_SERVICE_KEY')
url = 'https://apis.data.go.kr/B553881/newRegistlnfoService_02/getnewRegistlnfoService02'

params = {
    'serviceKey' : service_key,
    'registYy' : '2017',
    'registMt' : '10',
    'vhctyAsortCode' : 1,
    'registGrcCode' : 1
}

response = requests.get(url,params=params)
print(f'code: {response.status_code}')
print(response.text)   # 문자열 xml 구조

root = ET.fromstring(response.text)

for child in root.find('header'):  # Element 객체
    print(child.tag, child.text)

for child in root.find('body'): # Element 객체
    print(child.tag, child.text)

# print(root.findtext('header/resultCode'))
# print(root.findtext('header/resultMsg'))
# print(root.findtext('body/dtaCo'))
# Out:
# code: 200
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL_CODE</resultMsg></header><body><dtaCo>16616</dtaCo></body></response>
# resultCode 00
# resultMsg NORMAL_CODE
# dtaCo 16616

# %%
# %pip install xmltodict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmltodict
data = xmltodict.parse(response.text)

print(data)
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}, 'body': {'dtaCo': '16616'}}}

# %% [markdown]
# db 구성
# table:
# - 차량종류: 승용, 승합, 화물, 특수
# - 등록지역: 서울, 인천, 경기 (수도권)
# - 차량유형: 자가용, 영업용, 관용
# - 국산수입 구분명: 국산, 외산
